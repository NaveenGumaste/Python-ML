# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x=np. array ([1,5,13,25,33,46]).reshape ((-1,1))
y=np. array ([3,6,9,42,24,18])

plt.scatter(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)
