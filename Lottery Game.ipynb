# %%
import random
import pandas as pd

computer_wins = 0
user_wins = 0

for i in range(10):
    computer = random.randint(1, 9)
    user_input = int(input("Enter the number between 1 and 9: "))
    print(f"Computer: {computer}")
    print(f"User: {user_input}")
    if computer > user_input:
        print("Computer won")
        computer_wins += 1
    elif computer == user_input:
        print("Tie")
    else:
        print("You won")
        user_wins += 1

data = {"Computer Wins": [computer_wins], "User Wins": [user_wins]}
df = pd.DataFrame(data)

csv_filename = 'LoterryData.csv'
df.to_csv(csv_filename, index=False)

print(f"Data saved to {csv_filename}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Kle_Tech\BE\Programs\Python ML\Lottery Game.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/d%3A/Kle_Tech/BE/Programs/Python%20ML/Lottery%20Game.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import random
# ----> <a href='vscode-notebook-cell:/d%3A/Kle_Tech/BE/Programs/Python%20ML/Lottery%20Game.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/d%3A/Kle_Tech/BE/Programs/Python%20ML/Lottery%20Game.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> computer_wins = 0
#       <a href='vscode-notebook-cell:/d%3A/Kle_Tech/BE/Programs/Python%20ML/Lottery%20Game.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> user_wins = 0
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
import matplotlib.pyplot as plt

csv_filename = 'LoterryData.csv'
df = pd.read_csv(csv_filename)

computer_wins = df['Computer Wins'][0]
user_wins = df['User Wins'][0]

labels = ['Computer Wins', 'User Wins']
values = [computer_wins, user_wins]

plt.bar(labels, values, color=['blue', 'green'])
plt.xlabel('Outcome')
plt.ylabel('Number of Wins')
plt.title('Computer vs User Wins')
plt.show()
