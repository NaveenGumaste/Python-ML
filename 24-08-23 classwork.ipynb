# %% [markdown]
# ***matplotlib***

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.2

# %% [markdown]
# ***Stright Line***

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,1,10)
m=0.6
c=25
y=m*x+c
plt.plot(x,y)
plt.show()

# %% [markdown]
# ***Sine Wave Generation***

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,10,100)
y=6+3*np.sin(2*x)
fig,a=plt.subplots()
a.plot(x,y,linewidth=2.0)
a.set(xlim=(0,8),xticks=np.arange(1,8),
      ylim=(0,8),yticks=np.arange(1,8))
plt.show()

# %% [markdown]
# ***Sine Wave Generation 2***

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,10,100)
y=6+3*np.sin(2*x)
fig,a=plt.subplots()
a.plot(x,y,linewidth=2.0)
a.set(xlim=(0,8),xticks=np.arange(1,8),
      ylim=(0,8),yticks=np.arange(1,8))
plt.show()

# %% [markdown]
# ***Sine Wave Generation3***

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,10,100)
y=4+3*np.sin(2*x)
fig,a=plt.subplots()
a.plot(x,y,linewidth=2.0)
a.set(xlim=(0,8),xticks=np.arange(1,8),
      ylim=(0,8),yticks=np.arange(1,8))
plt.show()

# %% [markdown]
# ***Sine Wave Generation With Structure***

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('_mpl-gallery')
x=np.linspace(0,10,100)
y=6+3*np.sin(2*x)
fig,a=plt.subplots()
a.plot(x,y,linewidth=2.0)
a.set(xlim=(0,8),xticks=np.arange(1,8),
      ylim=(0,8),yticks=np.arange(1,8))
plt.show()

# %% [markdown]
# ***Scatter plot***

# %%
import matplotlib.pyplot as plt
import numpy as np
temp=np.array([10,20,25,30,40,50,60,70,80,90,100,110,120])
res=np.array([18476,12185,10000,8260,5740,4080,2960,2188,1645,1257,973,765,608])
plt.scatter(temp,res)
plt.show()

# %% [markdown]
# ***Exponential***

# %%
import matplotlib.pyplot as plt
import numpy as np
temp=np.array([10,20,25,30,40,50,60,70,80,90,100,110,120])
res=np.array([18476,12185,10000,8260,5740,4080,2960,2188,1645,1257,973,765,608])
plt.plot(temp,res)
plt.show()

# %% [markdown]
# ***Exponential with Points***

# %%
import matplotlib.pyplot as plt
import numpy as np
temp=np.array([10,20,25,30,40,50,60,70,80,90,100,110,120])
res=np.array([18476,12185,10000,8260,5740,4080,2960,2188,1645,1257,973,765,608])
plt.plot(res,marker='*')
plt.show()

# %% [markdown]
# ***Exponential with Points 2***

# %%
import matplotlib.pyplot as plt
import numpy as np
temp=np.array([10,20,25,30,40,50,60,70,80,90,100,110,120])
res=np.array([18476,12185,10000,8260,5740,4080,2960,2188,1645,1257,973,765,608])
plt.plot(res,linestyle='dotted')
plt.show()

# %% [markdown]
# ***Thermistor***

# %%
import matplotlib.pyplot as plt
import numpy as np
temp=np.array([10,20,25,30,40,50,60,70,80,90,100,110,120])
res=np.array([18476,12185,10000,8260,5740,4080,2960,2188,1645,1257,973,765,608])
plt.plot(temp,res)
plt.grid()
plt.show()
plt.title("thermistor characteristics")
plt.xlabel("temp")
plt.ylabel("res")
# Out:
# Text(0, 0.5, 'res')

# %% [markdown]
# ***Bar Graph***

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["karnataka","ap","tn","tg"])
y=np.array([65,68,69,86])
plt.bar(x,y)
plt.show()

# %% [markdown]
# ***Bar graph 2***

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["karnataka","ap","tn","tg"])
y=np.array([65,68,69,86])
plt.bar(x,y)
plt.show()
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(5,1,100000)
plt.hist(x,1000)
plt.show()

# %%
import random
import numpy
import matplotlib.pyplot as plt
x=numpy.random.randint(0,100)
plt.hist(x,10)
plt.show()

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.0.3

# %%
pip install scipy
# Out:
# Collecting scipy
#   Using cached scipy-1.11.2-cp311-cp311-win_amd64.whl (44.0 MB)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\navee\appdata\local\programs\python\python311\lib\site-packages (from scipy) (1.25.2)
# Installing collected packages: scipy
# Successfully installed scipy-1.11.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from scipy import stats

# Read CSV file into a DataFrame
data = pd.read_csv("marks_data.csv")

# Calculate mean, median, and mode for each column
statistics = {}
for column in data.columns:
    column_data = data[column]
    mean = column_data.mean()
    median = column_data.median()
    mode = stats.mode(column_data)[0][0]  # Mode returns a ModeResult object, we're interested in the mode value
    statistics[column] = {'Mean': mean, 'Median': median, 'Mode': mode}

# Display computed statistics
for column, stats_dict in statistics.items():
    print(f"Column: {column}")
    print(f"Mean: {stats_dict['Mean']}")
    print(f"Median: {stats_dict['Median']}")
    print(f"Mode: {stats_dict['Mode']}")
    print("-" * 20)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 2
#       1 import pandas as pd
# ----> 2 from scipy import stats
#       4 # Read CSV file into a DataFrame
#       5 data = pd.read_csv("marks_data.csv")
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\__init__.py:202, in __getattr__(name)
#     200 def __getattr__(name):
#     201     if name in submodules:
# --> 202         return _importlib.import_module(f'scipy.{name}')
#     203     else:
#     204         try:
#
# File c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\__init__.py:608
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     603
#     604 """
#     606 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     607                                DegenerateDataWarning, FitError)
# --> 608 from ._stats_py import *
#     609 from ._variation import variation
#     610 from .distributions import *
#
# File c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_stats_py.py:46
#      44 import scipy.special as special
#      45 from scipy import linalg
# ---> 46 from . import distributions
#      47 from . import _mstats_basic as mstats_basic
#      48 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#      49                                    siegelslopes)
#
# File c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\distributions.py:8
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
# ----> 8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
#      10 from . import _continuous_distns
#      11 from . import _discrete_distns
#
# File c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_distn_infrastructure.py:23
#      18 from scipy.special import comb, entr
#      21 # for root finding for continuous distribution ppf, and maximum likelihood
#      22 # estimation
# ---> 23 from scipy import optimize
#      25 # for functions of continuous distributions (e.g. moments, entropy, cdf)
#      26 from scipy import integrate
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\__init__.py:202, in __getattr__(name)
#     200 def __getattr__(name):
#     201     if name in submodules:
# --> 202         return _importlib.import_module(f'scipy.{name}')
#     203     else:
#     204         try:
#
# File c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\__init__.py:422
#     420 from ._nnls import nnls
#     421 from ._basinhopping import basinhopping
# --> 422 from ._linprog import linprog, linprog_verbose_callback
#     423 from ._lsap import linear_sum_assignment
#     424 from ._differentialevolution import differential_evolution
#
# File c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_linprog.py:24
#      22 from ._linprog_ip import _linprog_ip
#      23 from ._linprog_simplex import _linprog_simplex
# ---> 24 from ._linprog_rs import _linprog_rs
#      25 from ._linprog_doc import (_linprog_highs_doc, _linprog_ip_doc,
#      26                            _linprog_rs_doc, _linprog_simplex_doc,
#      27                            _linprog_highs_ipm_doc, _linprog_highs_ds_doc)
#      28 from ._linprog_util import (
#      29     _parse_linprog, _presolve, _get_Abc, _LPProblem, _autoscale,
#      30     _postsolve, _check_result, _display_summary)
#
# File c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_linprog_rs.py:25
#      23 from scipy.linalg import solve
#      24 from ._optimize import _check_unknown_options
# ---> 25 from ._bglu_dense import LU
#      26 from ._bglu_dense import BGLU as BGLU
#      27 from ._linprog_util import _postsolve
#
# File <frozen importlib._bootstrap>:405, in parent(self)
#
# KeyboardInterrupt:

# %%
import random
import pandas as pd
import os

# Create a folder to save CSV files if it doesn't exist
output_folder = './Csv'
os.makedirs(output_folder, exist_ok=True)

computer_wins = 0
user_wins = 0

for i in range(10):
    computer = random.randint(1, 9)
    user_input = int(input("Enter the number between 1 and 9: "))
    print(f"Computer: {computer}")
    print(f"User: {user_input}")
    if computer > user_input:
        print("Computer won")
        computer_wins += 1
    elif computer == user_input:
        print("Tie")
    else:
        print("You won")
        user_wins += 1

data = {"Computer Wins": [computer_wins], "User Wins": [user_wins]}
df = pd.DataFrame(data)

csv_filename = os.path.join(output_folder, 'Data.csv')
df.to_csv(csv_filename, index=False)

print(f"Data saved to {csv_filename}")
# Out:
# Computer: 4
# User: 3
# Computer won
# Computer: 4
# User: 4
# Tie
# Computer: 4
# User: 5
# You won
# Computer: 8
# User: 6
# Computer won
# Computer: 1
# User: 7
# You won
# Computer: 5
# User: 7
# You won
# Computer: 5
# User: 8
# You won
# Computer: 4
# User: 9
# You won
# Computer: 5
# User: 1
# Computer won
# Computer: 3
# User: 2
# Computer won
# Data saved to ./Csv\Data.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

csv_filename = 'output.csv'
df = pd.read_csv(csv_filename)

computer_wins = df['Computer Wins'][0]
user_wins = df['User Wins'][0]

labels = ['Computer Wins', 'User Wins']
values = [computer_wins, user_wins]

plt.bar(labels, values, color=['blue', 'green'])
plt.xlabel('Outcome')
plt.ylabel('Number of Wins')
plt.title('Computer vs User Wins')
plt.show()
